# %%
import pandas as pd

# %%
df=pd.read_csv("pp-2022.csv",header=None)

# %%
df.set_axis(['Transaction unique identifier','Price','Date of Transfer','Postcode','Property Type','Old/New','Duration',
             'PAON','SAON','Street','Locality','Town/City','District','County','PPD Category Type','Record Status'], 
            axis='columns', inplace=True)

# %%
lst_columns=['Postcode','Property Type','Old/New','Duration',
             'PAON','SAON','Street','Locality','Town/City','District','County','PPD Category Type','Record Status']

# %%
for i in lst_columns:
    df[i] = df[i].astype(pd.StringDtype())

# %%
df.head()
# Out:
#             Transaction unique identifier   Price  Date of Transfer  Postcode  \
# 0  {DBA933FA-5665-669D-E053-6B04A8C0AD56}  232999  2022-01-27 00:00  HU15 1FT
# 1  {DBA933FA-5666-669D-E053-6B04A8C0AD56}  367250  2022-02-25 00:00  HU17 9RT
# 2  {DBA933FA-5668-669D-E053-6B04A8C0AD56}  425000  2022-02-18 00:00  HU14 3EZ
# 3  {DBA933FA-566B-669D-E053-6B04A8C0AD56}  217000  2022-02-18 00:00  DN14 7ZL
# 4  {DBA933FA-566E-669D-E053-6B04A8C0AD56}  189950  2022-01-31 00:00  YO16 6AE
#
#   Property Type Old/New Duration           PAON          SAON  \
# 0             F       N        L   FAIRWAY VIEW  APARTMENT 27
# 1             D       N        F  ASHCROFT, 216
# 2             D       N        F              4
# 3             S       N        F             59
# 4             D       N        F              6
#
#                Street Locality      Town/City                  District  \
# 0     ELLOUGHTON ROAD                  BROUGH  EAST RIDING OF YORKSHIRE
# ...

# %%
df.iloc[4,:]
# Out:
# Transaction unique identifier    {DBA933FA-566E-669D-E053-6B04A8C0AD56}
# Price                                                            189950
# Date of Transfer                                       2022-01-31 00:00
# Postcode                                                       YO16 6AE
# Property Type                                                         D
# Old/New                                                               N
# Duration                                                              F
# PAON                                                                  6
# SAON
# Street                                                  ALDERSHOT DRIVE
# Locality
# Town/City                                                   BRIDLINGTON
# District                                       EAST RIDING OF YORKSHIRE
# County                                         EAST RIDING OF YORKSHIRE
# PPD Category Type                                                     A
# ...

# %%
a=df["Town/City"].unique()
b=sorted(a)
b[50:]
# Out:
# ['BALA',
#  'BALDOCK',
#  'BAMBURGH',
#  'BAMPTON',
#  'BANBURY',
#  'BANGOR',
#  'BANSTEAD',
#  'BANWELL',
#  'BARGOED',
#  'BARKING',
#  'BARMOUTH',
#  'BARNARD CASTLE',
#  'BARNET',
#  'BARNETBY',
#  'BARNOLDSWICK',
#  'BARNSLEY',
#  'BARNSTAPLE',
#  'BARROW-IN-FURNESS',
#  'BARROW-UPON-HUMBER',
#  'BARRY',
#  'BARTON-UPON-HUMBER',
#  'BASILDON',
#  'BASINGSTOKE',
#  'BATH',
#  'BATLEY',
#  'BATTLE',
#  'BEACONSFIELD',
#  'BEAMINSTER',
#  'BEAUMARIS',
#  'BEAWORTHY',
#  'BECCLES',
#  'BECKENHAM',
#  'BECKERMET',
#  'BEDALE',
#  'BEDFORD',
#  'BEDLINGTON',
#  'BEDWORTH',
#  'BELFORD',
#  'BELPER',
#  'BELVEDERE',
#  'BEMBRIDGE',
#  'BENFLEET',
#  'BERKELEY',
#  'BERKHAMSTED',
#  'BERWICK-UPON-TWEED',
#  'BETCHWORTH',
#  'BETWS-Y-COED',
#  'BEVERLEY',
#  'BEWDLEY',
#  'BEXHILL-ON-SEA',
#  'BEXLEY',
#  'BEXLEYHEATH',
#  'BICESTER',
#  'BIDEFORD',
#  'BIGGLESWADE',
#  'BILLERICAY',
#  'BILLINGHAM',
#  'BILLINGSHURST',
#  'BILSTON',
#  'BINGLEY',
#  'BIRCHINGTON',
#  'BIRKENHEAD',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299433 entries, 0 to 299432
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Transaction unique identifier  299433 non-null  object
#  1   Price                          299433 non-null  int64
#  2   Date of Transfer               299433 non-null  object
#  3   Postcode                       298991 non-null  string
#  4   Property Type                  299433 non-null  string
#  5   Old/New                        299433 non-null  string
#  6   Duration                       299433 non-null  string
#  7   PAON                           299433 non-null  string
#  8   SAON                           34769 non-null   string
#  9   Street                         294778 non-null  string
#  10  Locality                       108165 non-null  string
#  11  Town/City                      299433 non-null  string
# ...

# %%
df=df.fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299433 entries, 0 to 299432
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Transaction unique identifier  299433 non-null  object
#  1   Price                          299433 non-null  int64
#  2   Date of Transfer               299433 non-null  object
#  3   Postcode                       299433 non-null  string
#  4   Property Type                  299433 non-null  string
#  5   Old/New                        299433 non-null  string
#  6   Duration                       299433 non-null  string
#  7   PAON                           299433 non-null  string
#  8   SAON                           299433 non-null  string
#  9   Street                         299433 non-null  string
#  10  Locality                       299433 non-null  string
#  11  Town/City                      299433 non-null  string
# ...

# %%
#df1=df['Postcode']
df['House_Unique']=df['PAON']+' '+df['SAON']+' '+df['Street']+' '+df['Locality']

# %%
df['Postcode'].unique()
# Out:
# <StringArray>
# ['HU15 1FT', 'HU17 9RT', 'HU14 3EZ', 'DN14 7ZL', 'YO16 6AE', 'YO43 4DU',
#  'BD18 1LR',   'S3 9DE',  'HD3 3JB',  'HD3 4EP',
#  ...
#   'WV8 2JP',  'WS7 4UW',  'CW3 9PW', 'ST10 1TN', 'WS13 8TN',  'WV3 9DP',
#   'B77 2PB', 'ST14 5AE', 'ST14 5FG', 'ST21 6NY']
# Length: 240320, dtype: string

# %%
df['Postcode'].unique()

# %%
df[df['Property Type']=='F']
# Out:
#                  Transaction unique identifier   Price  Date of Transfer  \
# 0       {DBA933FA-5665-669D-E053-6B04A8C0AD56}  232999  2022-01-27 00:00
# 53      {DBA933FA-51A9-669D-E053-6B04A8C0AD56}  174000  2022-02-11 00:00
# 55      {DBA933FA-51AF-669D-E053-6B04A8C0AD56}  151000  2022-02-21 00:00
# 66      {E53EDD2D-A31C-83EC-E053-6B04A8C03A59}  135000  2022-06-22 00:00
# 71      {DBA933FA-4626-669D-E053-6B04A8C0AD56}  154000  2022-01-05 00:00
# ...                                        ...     ...               ...
# 299335  {DE2D0CE0-1B19-51EE-E053-6C04A8C00671}  290000  2022-03-29 00:00
# 299340  {DE2D0CE0-1F7C-51EE-E053-6C04A8C00671}  177000  2022-03-25 00:00
# 299395  {DE2D0CE0-12A8-51EE-E053-6C04A8C00671}  102000  2022-02-28 00:00
# 299405  {DE2D0CE0-1675-51EE-E053-6C04A8C00671}  600000  2022-03-11 00:00
# 299413  {DE2D0CE0-1682-51EE-E053-6C04A8C00671}  230000  2022-03-31 00:00
#
#         Postcode Property Type Old/New Duration                  PAON  \
# ...

# %%
df[df['Old/New']=='Y']
# Out:
#                  Transaction unique identifier   Price  Date of Transfer  \
# 1290    {DBA933FA-59DB-669D-E053-6B04A8C0AD56}  319950  2022-01-14 00:00
# 1291    {DBA933FA-59DD-669D-E053-6B04A8C0AD56}  330950  2022-01-28 00:00
# 1292    {DBA933FA-59DE-669D-E053-6B04A8C0AD56}  253950  2022-02-04 00:00
# 1293    {DBA933FA-59DF-669D-E053-6B04A8C0AD56}  284000  2022-02-11 00:00
# 1294    {DBA933FA-59E3-669D-E053-6B04A8C0AD56}  291950  2022-02-18 00:00
# ...                                        ...     ...               ...
# 296801  {E53EDD2E-ADC3-83EC-E053-6B04A8C03A59}  105000  2022-05-17 00:00
# 296802  {E53EDD2E-ADC4-83EC-E053-6B04A8C03A59}  105000  2022-05-17 00:00
# 296804  {E53EDD2E-ADC6-83EC-E053-6B04A8C03A59}  590000  2022-02-25 00:00
# 298441  {DE2D0CE0-0C7F-51EE-E053-6C04A8C00671}  460746  2022-03-04 00:00
# 298444  {DE2D0CE0-0C84-51EE-E053-6C04A8C00671}  597995  2022-04-20 00:00
#
#         Postcode Property Type Old/New Duration              PAON    SAON  \
# ...
